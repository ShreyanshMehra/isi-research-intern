# %%
import pandas as pd

# %%
df=pd.read_csv("Dataset\merged_rabi_rice_reservoir.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\shrey\AppData\Local\Temp\ipykernel_32364\923664193.py:1: SyntaxWarning: invalid escape sequence '\m'
#   df=pd.read_csv("Dataset\merged_rabi_rice_reservoir.csv")

# %%
df.head()
# Out:
#        state_name crop_name  apy_item_interval_start  \
# 0  Andhra Pradesh      rice                     2000
# 1  Andhra Pradesh      rice                     2000
# 2  Andhra Pradesh      rice                     2000
# 3  Andhra Pradesh      rice                     2000
# 4  Andhra Pradesh      rice                     2000
#
#   temperature_recorded_date  state_temperature_max_val  \
# 0                2000-01-01                      30.38
# 1                2000-01-02                      30.04
# 2                2000-01-03                      29.92
# 3                2000-01-04                      29.98
# 4                2000-01-05                      29.77
#
#    state_temperature_min_val  state_rainfall_val    yield         FRL  \
# 0                      14.47                 0.0  3.58525  152.296667
# 1                      13.96                 0.0  3.58525  152.296667
# 2                      12.98                 0.0  3.58525  152.296667
# ...

# %%
df_gpt=df.head(1000)

# %%
df_gpt.to_csv("G:\ISI intern\Dataset\df_gpt.csv",index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\shrey\AppData\Local\Temp\ipykernel_32364\2432918478.py:1: SyntaxWarning: invalid escape sequence '\I'
#   df_gpt.to_csv("G:\ISI intern\Dataset\df_gpt.csv",index=False)
